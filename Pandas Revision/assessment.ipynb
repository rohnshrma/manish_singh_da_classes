# %% [markdown]
# # Practical Data Analysis Assignment
#
# This assignment helps you practice Pandas basics using the `coffee_shop_sales.csv` dataset, focusing on creating Series and DataFrames, indexing, reading CSV files, and basic data inspection as shown in the provided code.
#
# ## Instructions
# - Use the `coffee_shop_sales.csv` dataset for all tasks.
# - Only use Pandas techniques shown in the provided code (e.g., Series, DataFrames, `loc`, `head`, `tail `
#
# System: It looks like the artifact generation was cut off. I'll provide the complete markdown file for the data analysis assignment as requested, formatted as a downloadable markdown file, using only the Pandas techniques from the provided code.
#
# <xaiArtifact artifact_id="b4af0e89-f01a-41b4-9da4-a09659d6b480" artifact_version_id="f50e7421-4a29-4c9c-9705-ad60fc64da81" title="Data_Analysis_Assignment.md" contentType="text/markdown">
#
# # Practical Data Analysis Assignment
#
# This assignment is designed to reinforce Pandas concepts using the `coffee_shop_sales.csv` dataset, focusing on creating Series and DataFrames, indexing, reading CSV files, and basic data inspection as demonstrated in the provided code.
#
# ## Instructions
# - Use the `coffee_shop_sales.csv` dataset for all tasks.
# - Only use Pandas techniques shown in the provided code (e.g., Series, DataFrames, `loc`, `head`, `tail`, `info`, and setting display options).
# - Submit your code and answers as a Python script or Jupyter notebook.
# - Include clear comments explaining each step.
# - Ensure all outputs are displayed (e.g., print DataFrames, Series, or specific values).
#
# ## Assignment Tasks
#
# ### 1. Data Loading and Inspection
# - Load the `coffee_shop_sales.csv` dataset into a Pandas DataFrame named `coffee_df`.
# - Display the first 5 rows and the last 5 rows of the dataset using appropriate methods.
# - Print the structure of the dataset (e.g., column names, non-null counts, and data types).
# - Set Pandas to display all rows of the DataFrame when printed.
#
# ### 2. Creating a Series
# - Create a Pandas Series named `sales_series` from the `Total Sales` column of the `coffee_df` DataFrame.
# - Assign custom indices to `sales_series` using the `Transaction ID` column.
# - Print the entire `sales_series` and then print the `Total Sales` value for `Transaction ID` 10.
#
# ### 3. Creating a DataFrame with Custom Index
# - Create a new DataFrame named `coffee_subset` containing only the `Store Location`, `Total Sales`, and `Customer Satisfaction` columns from `coffee_df`.
# - Set the `Transaction Month` column as the index for `coffee_subset`.
# - Display the entire `coffee_subset` DataFrame.
# - Use indexing to print the row corresponding to the `Transaction Month` "Jan".
#
# ### 4. Accessing Specific Rows
# - Using the `coffee_df` DataFrame, print the row with index 0 (first row) using numerical indexing.
# - Using the `coffee_subset` DataFrame from Task 3, print the `Customer Satisfaction` value for the row indexed by "Apr".
#
# ### 5. Handling Missing Data
# - Identify which columns in `coffee_df` have missing values by inspecting the DataFrame's structure.
# - Print all rows where `Customer Satisfaction` is missing (manually inspect the output from `coffee_df` to identify these rows).
#
# ### 6. Creating a New DataFrame
# - Create a dictionary called `summary_dict` with two keys: `Store Location` (containing unique store locations from `coffee_df`) and `Average Sales` (containing the average `Total Sales` for each store location, calculated manually or using basic arithmetic).
# - Convert `summary_dict` into a DataFrame named `summary_df` with `Store Location` as the index.
# - Display the `summary_df` DataFrame.
#
# ## Notes
# - For Task 6, calculate averages manually (e.g., sum `Total Sales` for each store and divide by the number of transactions) since advanced methods like `groupby` were not shown.
# - Treat negative values in `Total Sales` or `Items Sold` as valid data unless instructed otherwise.
# - Ensure your code is executable and produces the expected output based on the `coffee_shop_sales.csv` dataset.
#
# ## Submission
# - Submit a Python script or Jupyter notebook with the code for all tasks.
# - Include comments explaining each step.
# - Ensure outputs for each task are clearly displayed.
#
# ## Example Submission Structure
# ```python
# import pandas as pd
#
# # Task 1: Data Loading and Inspection
# # Load the dataset
# coffee_df = pd.read_csv("./coffee_shop_sales.csv")
# # Display first 5 rows
# print(coffee_df.head())
# # Display last 5 rows
# print(coffee_df.tail())
# # Display structure
# print(coffee_df.info())
# # Set display option for all rows
# pd.options.display.max_rows = 9999
# print(coffee_df)
#
# # Task 2: Creating a Series
# # ... (continue for all tasks)
# ```
#
# ## Grading Criteria
# - **Correctness (60%)**: Code produces the correct output using only the techniques shown.
# - **Clarity (20%)**: Code is well-commented and easy to follow.
# - **Completeness (20%)**: All tasks are attempted, and outputs are displayed as requested.
#
# Good luck with your Pandas practice!

# %%
import pandas as pd

coffee_df = pd.read_csv("./coffee_shop_sales.csv")

# %%
pd.options.display.max_rows= 9999

# %%
print(coffee_df)
# Out:
#      Transaction ID Transaction Month Store Location  Total Sales  Items Sold  \
# 0                 1               jan         Mumbai       250000         500
# 1                 2               JAN          Delhi       280000         550
# 2                 3              Jan       Bengaluru       220000         480
# 3                 4               jan        Chennai       260000         510
# 4                 5               Jan        Kolkata       230000         490
# 5                 6               feb         Mumbai       230000         490
# 6                 7               FEB          Delhi       270000         520
# 7                 8              Feb       Bengaluru       200000         460
# 8                 9               feb        Chennai       240000         500
# 9                10               Feb        Kolkata            0           0
# 10               11            march          Mumbai       260000         510
# ...
